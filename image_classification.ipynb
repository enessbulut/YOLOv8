# %% [markdown]
# <a href="https://colab.research.google.com/github/enessbulut/YOLOv8/blob/main/image_classification.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# drive'a bağlanma
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/YOLOv8/0_image_classification
# Out:
# /content/drive/MyDrive/YOLOv8/0_image_classification

# %%
# Ultralytics'i indir
# %pip install ultralytics

import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.7/112.6 GB disk)

# %% [markdown]
# Eğitim / Training

# %%
# Dosyaları Ayıklama
# !unzip data/covid_classification.zip -d ./data
# Out:
# Görüntülenen çıkış son 5000 satıra kısaltıldı.
#   inflating: ./data/covid_classification/train/normal/Normal-7307.png
#   inflating: ./data/covid_classification/train/normal/Normal-7308.png
#   inflating: ./data/covid_classification/train/normal/Normal-7309.png
#   inflating: ./data/covid_classification/train/normal/Normal-731.png
#   inflating: ./data/covid_classification/train/normal/Normal-7310.png
#   inflating: ./data/covid_classification/train/normal/Normal-7311.png
#   inflating: ./data/covid_classification/train/normal/Normal-7312.png
#   inflating: ./data/covid_classification/train/normal/Normal-7313.png
#   inflating: ./data/covid_classification/train/normal/Normal-7314.png
#   inflating: ./data/covid_classification/train/normal/Normal-7315.png
#   inflating: ./data/covid_classification/train/normal/Normal-7316.png
#   inflating: ./data/covid_classification/train/normal/Normal-7317.png
#   inflating: ./data/covid_classification/train/normal/Normal-7318.png
# ...

# %%
# Eğitim
# !yolo classify train \
model=yolov8l-cls.pt \
data=data/covid_classification \
imgsz=224 \
batch=32 \
epochs=50 \
device=0
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# ...

# %%
# !yolo classify predict model=/content/drive/MyDrive/YOLOv8/0_image_classification/runs/classify/train/weights/best.pt source=inference imgsz=224
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.9.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8l-cls summary (fused): 54 layers, 36,188,419 parameters, 0 gradients, 98.7 GFLOPs
#
# image 1/12 /content/drive/MyDrive/YOLOv8/0_image_classification/inference/COVID-1.png: 224x224 covid 0.99, normal 0.01, viral_pneumonia 0.00, 10.7ms
# image 2/12 /content/drive/MyDrive/YOLOv8/0_image_classification/inference/COVID-10.png: 224x224 covid 1.00, viral_pneumonia 0.00, normal 0.00, 10.8ms
# image 3/12 /content/drive/MyDrive/YOLOv8/0_image_classification/inference/COVID-6.png: 224x224 covid 1.00, viral_pneumonia 0.00, normal 0.00, 10.7ms
# image 4/12 /content/drive/MyDrive/YOLOv8/0_image_classification/inference/COVID-7.png: 224x224 covid 0.58, normal 0.42, viral_pneumonia 0.00, 10.8ms
# image 5/12 /content/drive/MyDrive/YOLOv8/0_image_classification/inference/Normal-25.png: 224x224 normal 1.00, covid 0.00, viral_pneumonia 0.00, 10.8ms
# ...

# %%
# %pip install ultralytics
import cv2
import numpy as np
from ultralytics import YOLO
img_path = "/content/drive/MyDrive/YOLOv8/0_image_classification/inference/COVID-10.png"
model = YOLO('/content/drive/MyDrive/YOLOv8/0_image_classification/runs/classify/train/weights/best.pt ') #modeli yükle
results = model(img_path) #resmi sınıflandır
class_dict = results[0].names
probs = results[0].probs.data.tolist()
print("sınıflar",class_dict)
print("olasılıklar:",probs)
print("sonuc:" , class_dict[np.argmax(probs)])
# Out:
# ...
#
# image 1/1 /content/drive/MyDrive/YOLOv8/0_image_classification/inference/COVID-10.png: 224x224 covid 1.00, viral_pneumonia 0.00, normal 0.00, 10.6ms
# Speed: 3.7ms preprocess, 10.6ms inference, 0.0ms postprocess per image at shape (1, 3, 224, 224)
# sınıflar {0: 'covid', 1: 'normal', 2: 'viral_pneumonia'}
# olasılıklar: [0.9999939203262329, 7.617137498527882e-08, 5.970207439531805e-06]
# sonuc: covid
