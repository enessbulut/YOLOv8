# %% [markdown]
# <a href="https://colab.research.google.com/github/enessbulut/YOLOv8/blob/main/Object_Tracking.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/YOLOv8/2_obj_tracking_and_counting
# Out:
# /content/drive/MyDrive/YOLOv8/2_obj_tracking_and_counting

# %%
# !pip install ultralytics

# %%
import ultralytics
ultralytics.checks()
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 41.7/112.6 GB disk)

# %%
# !yolo track model=yolov8m.pt source="/content/drive/MyDrive/YOLOv8/2_obj_tracking_and_counting/data/test.mp4" tracker="bytetrack.yaml"
# Byte-Track, BoT-Track
# Out:
# Ultralytics 8.4.14 🚀 Python-3.12.12 torch-2.10.0+cu128 CUDA:0 (Tesla T4, 14913MiB)
# YOLOv8m summary (fused): 92 layers, 25,886,080 parameters, 0 gradients, 78.9 GFLOPs
#
# video 1/1 (frame 1/456) /content/drive/MyDrive/YOLOv8/2_obj_tracking_and_counting/data/test.mp4: 384x640 3 cars, 108.6ms
# video 1/1 (frame 2/456) /content/drive/MyDrive/YOLOv8/2_obj_tracking_and_counting/data/test.mp4: 384x640 3 cars, 25.1ms
# video 1/1 (frame 3/456) /content/drive/MyDrive/YOLOv8/2_obj_tracking_and_counting/data/test.mp4: 384x640 4 cars, 26.1ms
# video 1/1 (frame 4/456) /content/drive/MyDrive/YOLOv8/2_obj_tracking_and_counting/data/test.mp4: 384x640 4 cars, 25.1ms
# video 1/1 (frame 5/456) /content/drive/MyDrive/YOLOv8/2_obj_tracking_and_counting/data/test.mp4: 384x640 4 cars, 25.1ms
# video 1/1 (frame 6/456) /content/drive/MyDrive/YOLOv8/2_obj_tracking_and_counting/data/test.mp4: 384x640 3 cars, 25.1ms
# ...
